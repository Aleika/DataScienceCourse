# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Aleika Lwiza A Fonsêca**
#
# Current: Back-end web developer / Future: Data Scientist

# %% [markdown]
# *I am interested in data science because I love to see how is possible to get informations about everything using data and how this informations can help and change the people's lives*
#
# *I want to be a data scientist to discover and explore the world through data*

# %% [markdown]
# ### A function that takes two integers numbers and prints the sum between them

# %%
def sum_integers(a, b):
    if not (isinstance(a, int) and isinstance(b, int)):
        print('The numbers must be integers.')
        return 
    
    sum = a+b
    print('The sum is', sum)

sum_integers(5,2)
# Out:
# The sum is 7

# %% [markdown]
# ***
# > For more information, feel free to talk to me!
#
#
# Author | Linkedin | Github
# --- | --- | ---
# *Aleika Alves* | <img src='https://icons.iconarchive.com/icons/iconsmind/outline/256/Linkedin-icon.png' width="45"> [Linkedin profile](https://www.linkedin.com/in/aleika-alves-b69967216) | ![alt text](https://avatars.githubusercontent.com/u/9919?s=40&v=4 )[Github profile](https://github.com/Aleika)
